# %%
#single classifier(same differen) 'baseline'

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Jul  9 13:45:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
!7z e "/content/drive/My Drive/celeba_png/img_align_celeba_png.7z.001" -o"/content/img/"

# %%
import os
import numpy as np
import pandas as pd
import sklearn.metrics as mt
from skimage import io, transform


import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler


# additional files is located in /home/jamal/Downloads/additional_files/
def save_checkpoint_high(state, filename='/content/drive/MyDrive/vre_autoencoder_final/trained_modes_final/checkpoint_propose_Male_celeb_high.pth.tar'):
    torch.save(state, filename)
def save_checkpoint_low(state, filename='/content/drive/MyDrive/vre_autoencoder_final/trained_modes_final/checkpoint_propose_Male_celeb_low.pth.tar'):
    torch.save(state, filename)
def save_checkpoint_class_MF(state, filename='/content/drive/MyDrive/vre_autoencoder_final/trained_modes_final/checkpoint_classification_propose_MF.pth.tar'):
    torch.save(state, filename)
def save_checkpoint_class_SD(state, filename='/content/drive/MyDrive/vre_autoencoder_final/trained_modes_final/checkpoint_classification_propose_SD.pth.tar'):
    torch.save(state, filename)

file_path ='/content/drive/MyDrive/list_attr_celeba1_train_used.txt'


images_path = '/content/img/' #train

load_net = 0

columns = ['ImgId','5_o_Clock_Shadow',
           ' Arched_Eyebrows', 'Attractive',
           'Bags_Under_Eyes', 'Bald', 'Bangs',
           'Big_Lips', 'Big_Nose', 'Black_Hair',
           'Blond_Hair', 'Blurry', 'Brown_Hair',
           'Bushy_Eyebrows', 'Chubby', 'Double_Chin',
           'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup',
           'High_Cheekbones', 'Male', 'Mouth_Slightly_Open', 'Mustache',
           'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose',
           'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair',
           'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young']


cele_attrib = pd.read_csv(file_path,delimiter = "\s+",names = columns)# lfw = cele_attrib.set_index('SUBJECT_ID')
lfw = cele_attrib


import torch
import torch.nn.functional as F
import torch.nn as nn

class VAE(nn.Module):
    def __init__(self, nc, ngf, ndf, latent_variable_size):
        super(VAE, self).__init__()

        self.nc = nc
        self.ngf = ngf
        self.ndf = ndf
        self.latent_variable_size = latent_variable_size

        # encoder
        self.e1 = nn.Conv2d(nc, self.ndf, 4, 2, 1)
        self.bn1 = nn.BatchNorm2d(self.ndf)

        self.e2 = nn.Conv2d(self.ndf, self.ndf*2, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(self.ndf*2)

        self.e3 = nn.Conv2d(ndf*2, ndf*4, 4, 2, 1)
        self.bn3 = nn.BatchNorm2d(ndf*4)

        self.e4 = nn.Conv2d(ndf*4, ndf*8, 4, 2, 1)
        self.bn4 = nn.BatchNorm2d(ndf*8)

        self.e5 = nn.Conv2d(ndf*8, ndf*8, 4, 2, 1)
        self.bn5 = nn.BatchNorm2d(ndf*8)

        self.fc1 = nn.Linear(ndf*8*4*4, latent_variable_size)
        self.fc2 = nn.Linear(ndf*8*4*4, latent_variable_size)

        # decoder
        self.d1 = nn.Linear(latent_variable_size, self.ngf*8*2*4*4)

        self.up1 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd1 = nn.ReplicationPad2d(1)
        self.d2 = nn.Conv2d(self.ngf*8*2, self.ngf*8, 3, 1)
        self.bn6 = nn.BatchNorm2d(self.ngf*8, 1.e-3)

        self.up2 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd2 = nn.ReplicationPad2d(1)
        self.d3 = nn.Conv2d(self.ngf*8, self.ngf*4, 3, 1)
        self.bn7 = nn.BatchNorm2d(self.ngf*4, 1.e-3)

        self.up3 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd3 = nn.ReplicationPad2d(1)
        self.d4 = nn.Conv2d(self.ngf*4, self.ngf*2, 3, 1)
        self.bn8 = nn.BatchNorm2d(self.ngf*2, 1.e-3)

        self.up4 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd4 = nn.ReplicationPad2d(1)
        self.d5 = nn.Conv2d(self.ngf*2, self.ngf, 3, 1)
        self.bn9 = nn.BatchNorm2d(self.ngf, 1.e-3)

        self.up5 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd5 = nn.ReplicationPad2d(1)
        self.d6 = nn.Conv2d(self.ngf, nc, 3, 1)

        self.leakyrelu = nn.LeakyReLU(0.2)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def encode(self, x):
        h1 = self.leakyrelu(self.bn1(self.e1(x)))
        h2 = self.leakyrelu(self.bn2(self.e2(h1)))
        h3 = self.leakyrelu(self.bn3(self.e3(h2)))
        h4 = self.leakyrelu(self.bn4(self.e4(h3)))
        h5 = self.leakyrelu(self.bn5(self.e5(h4)))
        h5 = h5.view(-1, self.ndf*8*4*4)

        return self.fc1(h5), self.fc2(h5), h5

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if use_cuda:
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        h1 = self.relu(self.d1(z))
        h1 = h1.view(-1, self.ngf*8*2, 4, 4)
        h2 = self.leakyrelu(self.bn6(self.d2(self.pd1(self.up1(h1)))))
        h3 = self.leakyrelu(self.bn7(self.d3(self.pd2(self.up2(h2)))))
        h4 = self.leakyrelu(self.bn8(self.d4(self.pd3(self.up3(h3)))))
        h5 = self.leakyrelu(self.bn9(self.d5(self.pd4(self.up4(h4)))))

        return self.sigmoid(self.d6(self.pd5(self.up5(h5))))

    def get_latent_var(self, x):
        mu, logvar, h1 = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        return z

    def forward(self, x):
        mu, logvar,h2 = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        res = self.decode(z)
        return res, mu, logvar, h2


class VAE_low(nn.Module):
    def __init__(self, nc, ngf, ndf, latent_variable_size):
        super(VAE_low, self).__init__()

        self.nc = nc
        self.ngf = ngf
        self.ndf = ndf
        self.latent_variable_size = latent_variable_size

        # encoder
        self.e1 = nn.Conv2d(nc, self.ndf, 4, 2, 1)
        self.bn1 = nn.BatchNorm2d(self.ndf)

        self.e2 = nn.Conv2d(self.ndf, self.ndf*2, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(self.ndf*2)

        self.e3 = nn.Conv2d(ndf*2, ndf*4, 4, 2, 1)
        self.bn3 = nn.BatchNorm2d(ndf*4)
        #
        # self.e4 = nn.Conv2d(ndf*4, ndf*4, 4, 2, 1)
        # self.bn4 = nn.BatchNorm2d(ndf*4)

        # self.e5 = nn.Conv2d(ndf*8, ndf*8, 4, 2, 1)
        # self.bn5 = nn.BatchNorm2d(ndf*8)

        self.fc1 = nn.Linear(ndf*4*4, latent_variable_size)
        self.fc2 = nn.Linear(ndf*4*4, latent_variable_size)

        # decoder
        self.d1 = nn.Linear(latent_variable_size, ngf*4*4)

        self.up1 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd1 = nn.ReplicationPad2d(1)
        self.d2 = nn.Conv2d(self.ngf, self.ngf//2, 3, 1)
        self.bn6 = nn.BatchNorm2d(self.ngf//2, 1.e-3)

        self.up2 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd2 = nn.ReplicationPad2d(1)
        self.d3 = nn.Conv2d(self.ngf, self.ngf//2, 3, 1)
        self.bn7 = nn.BatchNorm2d(self.ngf//2, 1.e-3)

        self.up3 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd3 = nn.ReplicationPad2d(1)
        self.d4 = nn.Conv2d(self.ngf*4, self.ngf*2, 3, 1)
        self.bn8 = nn.BatchNorm2d(self.ngf*2, 1.e-3)

        self.up4 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd4 = nn.ReplicationPad2d(1)
        self.d5 = nn.Conv2d(self.ngf*2, self.ngf, 3, 1)
        self.bn9 = nn.BatchNorm2d(self.ngf, 1.e-3)

        self.up5 = nn.UpsamplingNearest2d(scale_factor=2)
        self.pd5 = nn.ReplicationPad2d(1)
        self.d6 = nn.Conv2d(self.ngf//2, nc, 3, 1)

        self.leakyrelu = nn.LeakyReLU(0.2)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def encode(self, x):
        h1 = self.leakyrelu(self.bn1(self.e1(x)))
        h2 = self.leakyrelu(self.bn2(self.e2(h1)))
        h3 = self.leakyrelu(self.bn3(self.e3(h2)))
        # h4 = self.leakyrelu(self.bn4(self.e4(h3)))
        # h5 = self.leakyrelu(self.bn5(self.e5(h4)))
        h5 = h3.view(-1, self.ndf*4*4)

        return self.fc1(h5), self.fc2(h5),h5

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if use_cuda:
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        h1 = self.relu(self.d1(z))
        h1 = h1.view(-1, self.ngf, 4, 4)
        h2 = self.leakyrelu(self.bn6(self.d2(self.pd1(self.up1(h1)))))


        return self.sigmoid(self.d6(self.pd5(self.up5(h2))))

    def get_latent_var(self, x):
        mu, logvar,h5 = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        return z

    def forward(self, x):
        mu, logvar, h5 = self.encode(x.view(-1, self.nc, self.ndf, self.ngf))
        z = self.reparametrize(mu, logvar)
        res = self.decode(z)
        return res, mu, logvar, h5

# %%
class Net_A(nn.Module):

    def __init__(self):
        super(Net_A,self).__init__()

        self.ip3 = nn.Linear(2*560,2000,True)   # change the first parameter in case you change the size of the small image
        self.n3 = nn.BatchNorm1d(2000)
        self.n1 = nn.BatchNorm1d(2*560)
        self.ip4 = nn.Linear(2000,1000,True)
        self.n4 = nn.BatchNorm1d(1000)
        self.ip5 = nn.Linear(1000,128,True)
        self.n5 = nn.BatchNorm1d(128)
        self.ip6 = nn.Linear(128,2,True)

    def forward(self,x):
        x = self.n1(x)
        x2 = self.ip3(x)
        x2 = F.relu(x2)
        x2 = self.n3(x2)

        x2 = self.ip4(x2)
        x2 = F.relu(x2)
        x2 = self.n4(x2)

        x2 = self.ip5(x2)
        x2 = F.relu(x2)
        x2 = self.n5(x2)

        x2 = self.ip6(x2)
        x2 = F.relu(x2)




        # x2 = x2.mul(-1)
        # x = F.relu(x)
        # x = F.softmax(x,1)
        return x2


class Male_Female_dataset(Dataset):


   def __init__(self,root_dir,shape,transform=None):
     self.root_dir = root_dir
     self.transform = transform
     self.shape = shape

   def __len__(self):
     return len(cele_attrib)

   def __getitem__(self,idx):
    img1_name = os.path.join(self.root_dir,("{:06d}.png".format(idx+1)))
    image1 = io.imread(img1_name)
    image1 = transform.resize(image1,ip_shape)
    #print("Got image 1: {0}".format(image1))


    t = torch.rand(1)
    if t > 0.5:
        h = torch.randint(0,len(self),(1,1))
        img2_name = os.path.join(self.root_dir,("{:06d}.png".format(int(h)+1)))
        image2 = io.imread(img2_name)
        #print("Got image 2: {0}".format(image2))
        image2 = transform.resize(image2,self.shape)
        image2 = torch.Tensor.float(torch.from_numpy(image2))
        image2 = (torch.Tensor.permute(image2,(2,0,1)))
        image2 = image2/256.0
        image1 = torch.Tensor.float(torch.from_numpy(image1))
        image1 = (torch.Tensor.permute(image1,(2,0,1)))
        image1 = image1/256.0
        annot = 0
        gender = cele_attrib['Male'][idx]

    else:
        image2 = image1
        image2 = transform.resize(image2,self.shape)
        image2 = torch.Tensor.float(torch.from_numpy(image2))
        image2 = (torch.Tensor.permute(image2,(2,0,1)))
        image2 = image2/256.0
        image1 = torch.Tensor.float(torch.from_numpy(image1))
        image1 = (torch.Tensor.permute(image1,(2,0,1)))
        image1 = image1/256.0
        annot = 1
        gender = cele_attrib['Male'][idx]

    sample = {'image1' : image1,
                'image2' : image2,
                'same'   : annot,
                'gender' : gender}
    return sample




reconstruction_function = nn.BCELoss()
reconstruction_function.size_average = False


def loss_function(recon_x, x, mu, logvar):
    BCE = reconstruction_function(recon_x, x)

    # https://arxiv.org/abs/1312.6114 (Appendix B)
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)

    return BCE + KLD  


use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
shape = (16,16)
ip_shape = (128,128)
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 1-train_ratio-val_ratio
dataset = Male_Female_dataset(images_path,shape)


if load_net:
    model_high = VAE(nc=3, ngf=ip_shape[0], ndf=ip_shape[1], latent_variable_size=500).to(device)
    model_low = VAE_low(nc=3, ngf=shape[0], ndf=shape[1], latent_variable_size=60).to(device)
    class_net_SD = Net_A().to(device)
    class_net_MF = Net_A().to(device)

    checkpoint_high = torch.load('/content/drive/MyDrive/vre_autoencoder_final/trained_modes/checkpoint_propose_Male_celeb_high.pth.tar')
    checkpoint_low = torch.load('/content/drive/MyDrive/vre_autoencoder_final/trained_modes/checkpoint_propose_Male_celeb_low.pth.tar')
    checkpoint_class_SD = torch.load('/content/drive/MyDrive/vre_autoencoder_final/trained_modes/checkpoint_classification_propose_SD.pth.tar')
    checkpoint_class_SD = torch.load('/content/drive/MyDrive/vre_autoencoder_final/trained_modes/checkpoint_classification_propose_MF.pth.tar')

    model_high.load_state_dict ( checkpoint_high['state_dict'])
    model_low.load_state_dict ( checkpoint_low['state_dict'])
    class_net_SD.load_state_dict ( checkpoint_class_SD['state_dict'])
    class_net_MF.load_state_dict ( checkpoint_class_SD['state_dict'])

    optimizer_high = optim.Adam(model_high.parameters(),lr = 0.00001, weight_decay = 0.0005)
    optimizer_low = optim.Adam(model_low.parameters(),lr = 0.0001, weight_decay = 0.0005)
    optimizer_class_SD = optim.Adam(class_net_SD.parameters(),lr = 0.0001, weight_decay = 0.0005)
    optimizer_class_MF = optim.Adam(class_net_SD.parameters(),lr = 0.0001, weight_decay = 0.0005)

    optimizer_high.load_state_dict = checkpoint_high['optimizer']
    optimizer_low.load_state_dict = checkpoint_low['optimizer']
    optimizer_class_SD.load_state_dict = checkpoint_class_SD['optimizer']
    optimizer_class_MF.load_state_dict = checkpoint_class_SD['optimizer']



else:
    torch.cuda.empty_cache()
    model_high   = VAE(nc=3, ngf=ip_shape[0], ndf=ip_shape[1], latent_variable_size=500).to(device)
    model_low    = VAE_low(nc=3, ngf=shape[0], ndf=shape[1], latent_variable_size=60).to(device)
    class_net_SD = Net_A().to(device)
    #class_net_MF = Net_A().to(device)


    optimizer_high     = optim.Adam(model_high.parameters(),lr = 0.00001, weight_decay = 0.0005)
    optimizer_low      = optim.Adam(model_low.parameters(),lr = 0.00001, weight_decay = 0.0005)
    optimizer_class_SD = optim.Adam(class_net_SD.parameters(),lr = 0.000001, weight_decay = 0.0005)
    #optimizer_class_MF = optim.Adam(class_net_SD.parameters(),lr = 0.000001, weight_decay = 0.0005)

    checkpoint_class_SD= {'epoch':0}



index             = np.random.permutation(len(dataset)-5)
train_data_length = int(train_ratio*len(index))
val_data_length   = int(val_ratio*len(index))
test_data_length  = int(test_ratio*len(index))
train_index       = index[:train_data_length]
val_index         = index[train_data_length:(train_data_length+val_data_length)]
test_index        = index[train_data_length+val_data_length:]

train_dataloader = DataLoader(dataset,batch_size=50,sampler = SubsetRandomSampler(train_index))

err_same = []
err_gender = []

acc1_SD = []
acc1_MF = []

criterion2 = nn.CrossEntropyLoss()
t = -1
# Check if images are already exist in the folder if not then pass
for ep in range(checkpoint_class_SD['epoch'],5):
    for i,data in enumerate(train_dataloader):
        torch.cuda.empty_cache()
        optimizer_high.zero_grad()
        optimizer_low.zero_grad()
        optimizer_class_SD.zero_grad()
        # optimizer_class_MF.zero_grad()

        input1, input2 , label, gender = data.items()
        input1, input2 = input1[1].to(device), input2[1].to(device)
        label1 = label[1].to(device)
        gender = gender[1].to(device)
        gender = (gender+torch.ones_like(gender).to(device))//2



        recon_batch_high, mu_high, logvar_high, h2_h = model_high(input1)
        recon_batch_low, mu_low, logvar_low, h2_l = model_low(input2)

        mu_all = torch.cat((mu_high,mu_low),1)
        logvar_all = torch.cat((logvar_high,logvar_low),1)
        class_input = torch.cat((mu_all,logvar_all),1)
        #class_input = mu_all
        class_out_SD = class_net_SD(class_input)
        #class_out_MF = class_net_MF(class_input)



        loss_class_SD = criterion2(class_out_SD,label1)
        #loss_class_MF = criterion2(class_out_MF,gender)
        loss_high = loss_function(recon_batch_high, input1, mu_high, logvar_high)
        loss_low = loss_function(recon_batch_low, input2, mu_low, logvar_low)

        loss_class_SD.backward(retain_graph=True)
        #loss_class_MF.backward(retain_graph=True)
        loss_high.backward(retain_graph=True)
        loss_low.backward()


        optimizer_high.step()
        optimizer_low.step()
        optimizer_class_SD.step()
        #optimizer_class_MF.step()



        if (i%5==0):
            print ("HQ image reconstruction loss:",loss_high.item(),'iteration: ',i,"epoch: ",ep)
            print ("LQ image reconstruction loss:",loss_low.item(),'iteration: ',i,"epoch: ",ep)
            print ("Same Different Classification loss:", loss_class_SD.item(),'iteration: ',i,"epoch: ",ep)
            #print ("Male Female Classification loss:", loss_class_MF.item(),'iteration: ',i,"epoch: ",ep)
            print ("----------------------------------------------------")

        if (i%50==0):
            val_index1 = np.random.permutation(val_index)[:100]
            val_dataloader = DataLoader(dataset,batch_size=100,sampler = SubsetRandomSampler(val_index1))
            val_iter = iter(val_dataloader)

            total = 0
            correct1_SD = 0
            #correct1_MF = 0
            for j,dataj in enumerate(val_dataloader):
                input1j, input2j, labelj, gender = dataj.items()
                input1j, input2j = input1j[1].to(device), input2j[1].to(device)

                labelj = labelj[1].to(device)
                gender = gender[1].to(device)
                gender = (gender+torch.ones_like(gender).to(device))//2
                recon_batch_high, mu_high, logvar_high, h2_h = model_high(input1j)
                recon_batch_low, mu_low, logvar_low, h2_l = model_low(input2j)

                mu_all = torch.cat((mu_high,mu_low.data),1)
                logvar_all = torch.cat((logvar_high,logvar_low),1)
                class_input = torch.cat((mu_all,logvar_all),1)
                #class_input = mu_all
                class_out_SD = class_net_SD(class_input)
                # class_out_MF = class_net_MF(class_input)
                _,predicted1_SD = torch.max(class_out_SD.data,1)
                # _,predicted1_MF = torch.max(class_out_MF.data,1)
                # _,predicted2 = torch.max(output_A.data,1)
                total +=labelj.size(0)
                correct1_SD += (predicted1_SD == labelj).sum().item()
                # correct1_MF += (predicted1_MF == gender).sum().item()
                # correct2 += (predicted2 == gender).sum().item()
            print('Accuracy of SD: %d %%'%(100*correct1_SD/total))
            # print('Accuracy of MF: %d %%'%(100*correct1_MF/total))

            # print('Accuracy_MF: %d %%'%(100*correct2/total))

            acc1_SD.append(100*correct1_SD/total) #low high
            # acc1_MF.append(100*correct1_MF/total) #low high
            print('Mean Accuracy of SD: %d %%'%(np.mean(acc1_SD)))
            # print('Mean Accuracy of MF: %d %%'%(np.mean(acc1_MF)))
            print("----------------------------------------------------")
            # acc2.append(100*correct2/total) # male female
    # save_checkpoint_class_SD({
    #         'epoch': ep + 1,
    #         'state_dict': class_net_SD.state_dict(),

    #         'optimizer' : optimizer_class_SD.state_dict(),
    #     })
    # save_checkpoint_class_MF({
    #         'epoch': ep + 1,
    #         'state_dict': class_net_MF.state_dict(),

    #         'optimizer' : optimizer_class_MF.state_dict(),
    #     })
    save_checkpoint_high({
            'epoch': ep + 1,
            'state_dict': model_high.state_dict(),

            'optimizer' : optimizer_high.state_dict(),
        })
    save_checkpoint_low({
            'epoch': ep + 1,
            'state_dict': model_low.state_dict(),

            'optimizer' : optimizer_low.state_dict(),
        })

dataset.__getitem__(1)

# cele_attrib['Male'][1]
# Out:
# cuda
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:198: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
# HQ image reconstruction loss: 3365.263916015625 iteration:  0 epoch:  0
# LQ image reconstruction loss: 382.1661682128906 iteration:  0 epoch:  0
# Same Different Classification loss: 0.7429951429367065 iteration:  0 epoch:  0
# ----------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:253: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
# Streaming output truncated to the last 5000 lines.
# HQ image reconstruction loss: 2.1462724208831787 iteration:  2705 epoch:  2
# LQ image reconstruction loss: 0.5347188711166382 iteration:  2705 epoch:  2
# Same Different Classification loss: 0.6802847981452942 iteration:  2705 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8493207693099976 iteration:  2710 epoch:  2
# LQ image reconstruction loss: 0.45334839820861816 iteration:  2710 epoch:  2
# Same Different Classification loss: 0.5940033197402954 iteration:  2710 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9796782732009888 iteration:  2715 epoch:  2
# LQ image reconstruction loss: 0.5024057626724243 iteration:  2715 epoch:  2
# Same Different Classification loss: 0.6324771642684937 iteration:  2715 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.256618022918701 iteration:  2720 epoch:  2
# LQ image reconstruction loss: 0.5289703011512756 iteration:  2720 epoch:  2
# Same Different Classification loss: 0.590732216835022 iteration:  2720 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.161177396774292 iteration:  2725 epoch:  2
# LQ image reconstruction loss: 0.4878036677837372 iteration:  2725 epoch:  2
# Same Different Classification loss: 0.6302416324615479 iteration:  2725 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8087912797927856 iteration:  2730 epoch:  2
# LQ image reconstruction loss: 0.4534229636192322 iteration:  2730 epoch:  2
# Same Different Classification loss: 0.6208593249320984 iteration:  2730 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8027188777923584 iteration:  2735 epoch:  2
# LQ image reconstruction loss: 0.5047345757484436 iteration:  2735 epoch:  2
# Same Different Classification loss: 0.648389458656311 iteration:  2735 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.3319809436798096 iteration:  2740 epoch:  2
# LQ image reconstruction loss: 0.5743004083633423 iteration:  2740 epoch:  2
# Same Different Classification loss: 0.6621719598770142 iteration:  2740 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.6028285026550293 iteration:  2745 epoch:  2
# LQ image reconstruction loss: 0.6004162430763245 iteration:  2745 epoch:  2
# Same Different Classification loss: 0.5674207806587219 iteration:  2745 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.3261947631835938 iteration:  2750 epoch:  2
# LQ image reconstruction loss: 0.5199265480041504 iteration:  2750 epoch:  2
# Same Different Classification loss: 0.5733500719070435 iteration:  2750 epoch:  2
# ----------------------------------------------------
# Accuracy of SD: 58 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6557561159133911 iteration:  2755 epoch:  2
# LQ image reconstruction loss: 0.45552125573158264 iteration:  2755 epoch:  2
# Same Different Classification loss: 0.6736047863960266 iteration:  2755 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.6505649089813232 iteration:  2760 epoch:  2
# LQ image reconstruction loss: 0.4620997905731201 iteration:  2760 epoch:  2
# Same Different Classification loss: 0.6737931966781616 iteration:  2760 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.2780745029449463 iteration:  2765 epoch:  2
# LQ image reconstruction loss: 0.5169757604598999 iteration:  2765 epoch:  2
# Same Different Classification loss: 0.6319128274917603 iteration:  2765 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.618891954421997 iteration:  2770 epoch:  2
# LQ image reconstruction loss: 0.4793379306793213 iteration:  2770 epoch:  2
# Same Different Classification loss: 0.6364767551422119 iteration:  2770 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.023620367050171 iteration:  2775 epoch:  2
# LQ image reconstruction loss: 0.4489259421825409 iteration:  2775 epoch:  2
# Same Different Classification loss: 0.6524987816810608 iteration:  2775 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.7316782474517822 iteration:  2780 epoch:  2
# LQ image reconstruction loss: 0.5276708602905273 iteration:  2780 epoch:  2
# Same Different Classification loss: 0.630225658416748 iteration:  2780 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9875116348266602 iteration:  2785 epoch:  2
# LQ image reconstruction loss: 0.45710864663124084 iteration:  2785 epoch:  2
# Same Different Classification loss: 0.6216288208961487 iteration:  2785 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.0008790493011475 iteration:  2790 epoch:  2
# LQ image reconstruction loss: 0.4961324632167816 iteration:  2790 epoch:  2
# Same Different Classification loss: 0.6528679132461548 iteration:  2790 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.0965962409973145 iteration:  2795 epoch:  2
# LQ image reconstruction loss: 0.48140665888786316 iteration:  2795 epoch:  2
# Same Different Classification loss: 0.6774422526359558 iteration:  2795 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.589526653289795 iteration:  2800 epoch:  2
# LQ image reconstruction loss: 0.48868823051452637 iteration:  2800 epoch:  2
# Same Different Classification loss: 0.5862683057785034 iteration:  2800 epoch:  2
# ----------------------------------------------------
# Accuracy of SD: 54 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9589850902557373 iteration:  2805 epoch:  2
# LQ image reconstruction loss: 0.4454643428325653 iteration:  2805 epoch:  2
# Same Different Classification loss: 0.7169499397277832 iteration:  2805 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9987438917160034 iteration:  2810 epoch:  2
# LQ image reconstruction loss: 0.45405688881874084 iteration:  2810 epoch:  2
# Same Different Classification loss: 0.5774940848350525 iteration:  2810 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.1054539680480957 iteration:  2815 epoch:  2
# LQ image reconstruction loss: 0.5211476683616638 iteration:  2815 epoch:  2
# Same Different Classification loss: 0.6778648495674133 iteration:  2815 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.220244884490967 iteration:  2820 epoch:  2
# LQ image reconstruction loss: 0.5053748488426208 iteration:  2820 epoch:  2
# Same Different Classification loss: 0.6533557176589966 iteration:  2820 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6520110368728638 iteration:  2825 epoch:  2
# LQ image reconstruction loss: 0.48331573605537415 iteration:  2825 epoch:  2
# Same Different Classification loss: 0.569458544254303 iteration:  2825 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.3394687175750732 iteration:  2830 epoch:  2
# LQ image reconstruction loss: 0.5222837328910828 iteration:  2830 epoch:  2
# Same Different Classification loss: 0.6035812497138977 iteration:  2830 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8983234167099 iteration:  2835 epoch:  2
# LQ image reconstruction loss: 0.48100346326828003 iteration:  2835 epoch:  2
# Same Different Classification loss: 0.6708719730377197 iteration:  2835 epoch:  2
# ----------------------------------------------------
# HQ image reconstruction loss: 2.8667640686035156 iteration:  0 epoch:  3
# LQ image reconstruction loss: 0.4854958653450012 iteration:  0 epoch:  3
# Same Different Classification loss: 0.6365323662757874 iteration:  0 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 64 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 2.6267499923706055 iteration:  5 epoch:  3
# LQ image reconstruction loss: 0.5175744891166687 iteration:  5 epoch:  3
# Same Different Classification loss: 0.6274805665016174 iteration:  5 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8872181177139282 iteration:  10 epoch:  3
# LQ image reconstruction loss: 0.4695602059364319 iteration:  10 epoch:  3
# Same Different Classification loss: 0.6087288856506348 iteration:  10 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.7380757331848145 iteration:  15 epoch:  3
# LQ image reconstruction loss: 0.4421694874763489 iteration:  15 epoch:  3
# Same Different Classification loss: 0.6714413166046143 iteration:  15 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6838655471801758 iteration:  20 epoch:  3
# LQ image reconstruction loss: 0.48709744215011597 iteration:  20 epoch:  3
# Same Different Classification loss: 0.5942865610122681 iteration:  20 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9524658918380737 iteration:  25 epoch:  3
# LQ image reconstruction loss: 0.4775630831718445 iteration:  25 epoch:  3
# Same Different Classification loss: 0.6276504397392273 iteration:  25 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 2.0677764415740967 iteration:  30 epoch:  3
# LQ image reconstruction loss: 0.48249009251594543 iteration:  30 epoch:  3
# Same Different Classification loss: 0.6103057265281677 iteration:  30 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.9799385070800781 iteration:  35 epoch:  3
# LQ image reconstruction loss: 0.534896969795227 iteration:  35 epoch:  3
# Same Different Classification loss: 0.6410753726959229 iteration:  35 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.869505763053894 iteration:  40 epoch:  3
# LQ image reconstruction loss: 0.43350064754486084 iteration:  40 epoch:  3
# Same Different Classification loss: 0.5801821351051331 iteration:  40 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.885044813156128 iteration:  45 epoch:  3
# LQ image reconstruction loss: 0.5045700073242188 iteration:  45 epoch:  3
# Same Different Classification loss: 0.672981321811676 iteration:  45 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6692125797271729 iteration:  50 epoch:  3
# LQ image reconstruction loss: 0.4892882704734802 iteration:  50 epoch:  3
# Same Different Classification loss: 0.6142164468765259 iteration:  50 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 52 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 1.807706594467163 iteration:  55 epoch:  3
# LQ image reconstruction loss: 0.4678400456905365 iteration:  55 epoch:  3
# Same Different Classification loss: 0.6321931481361389 iteration:  55 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 2.1093926429748535 iteration:  60 epoch:  3
# LQ image reconstruction loss: 0.4468176066875458 iteration:  60 epoch:  3
# Same Different Classification loss: 0.6225095987319946 iteration:  60 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6429553031921387 iteration:  65 epoch:  3
# LQ image reconstruction loss: 0.43869295716285706 iteration:  65 epoch:  3
# Same Different Classification loss: 0.6010463833808899 iteration:  65 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.764101505279541 iteration:  70 epoch:  3
# LQ image reconstruction loss: 0.4661991000175476 iteration:  70 epoch:  3
# Same Different Classification loss: 0.573445737361908 iteration:  70 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6676851511001587 iteration:  75 epoch:  3
# LQ image reconstruction loss: 0.42827701568603516 iteration:  75 epoch:  3
# Same Different Classification loss: 0.6317602396011353 iteration:  75 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6029056310653687 iteration:  80 epoch:  3
# LQ image reconstruction loss: 0.39545738697052 iteration:  80 epoch:  3
# Same Different Classification loss: 0.6460105776786804 iteration:  80 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.8390381336212158 iteration:  85 epoch:  3
# LQ image reconstruction loss: 0.4623020589351654 iteration:  85 epoch:  3
# Same Different Classification loss: 0.6162062287330627 iteration:  85 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 2.0089375972747803 iteration:  90 epoch:  3
# LQ image reconstruction loss: 0.5017393827438354 iteration:  90 epoch:  3
# Same Different Classification loss: 0.6400936245918274 iteration:  90 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6149190664291382 iteration:  95 epoch:  3
# LQ image reconstruction loss: 0.42181968688964844 iteration:  95 epoch:  3
# Same Different Classification loss: 0.604684591293335 iteration:  95 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.5836821794509888 iteration:  100 epoch:  3
# LQ image reconstruction loss: 0.481523334980011 iteration:  100 epoch:  3
# Same Different Classification loss: 0.5927916169166565 iteration:  100 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 63 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6900804042816162 iteration:  105 epoch:  3
# LQ image reconstruction loss: 0.4621616303920746 iteration:  105 epoch:  3
# Same Different Classification loss: 0.622911810874939 iteration:  105 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.6263195276260376 iteration:  110 epoch:  3
# LQ image reconstruction loss: 0.4776638448238373 iteration:  110 epoch:  3
# Same Different Classification loss: 0.5853070616722107 iteration:  110 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.5189578533172607 iteration:  115 epoch:  3
# LQ image reconstruction loss: 0.4003284275531769 iteration:  115 epoch:  3
# Same Different Classification loss: 0.6146710515022278 iteration:  115 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.5854679346084595 iteration:  120 epoch:  3
# LQ image reconstruction loss: 0.5010628700256348 iteration:  120 epoch:  3
# Same Different Classification loss: 0.6839136481285095 iteration:  120 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.5349321365356445 iteration:  125 epoch:  3
# LQ image reconstruction loss: 0.4926397204399109 iteration:  125 epoch:  3
# Same Different Classification loss: 0.6087043881416321 iteration:  125 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.5415717363357544 iteration:  130 epoch:  3
# LQ image reconstruction loss: 0.4525674283504486 iteration:  130 epoch:  3
# Same Different Classification loss: 0.6229472160339355 iteration:  130 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.3559551239013672 iteration:  135 epoch:  3
# LQ image reconstruction loss: 0.48261210322380066 iteration:  135 epoch:  3
# Same Different Classification loss: 0.5971738696098328 iteration:  135 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.2861227989196777 iteration:  140 epoch:  3
# LQ image reconstruction loss: 0.46983835101127625 iteration:  140 epoch:  3
# Same Different Classification loss: 0.645067572593689 iteration:  140 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.252800703048706 iteration:  145 epoch:  3
# LQ image reconstruction loss: 0.4452834725379944 iteration:  145 epoch:  3
# Same Different Classification loss: 0.6525527834892273 iteration:  145 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.3087338209152222 iteration:  150 epoch:  3
# LQ image reconstruction loss: 0.4550737738609314 iteration:  150 epoch:  3
# Same Different Classification loss: 0.6063490509986877 iteration:  150 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 62 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 1.1633577346801758 iteration:  155 epoch:  3
# LQ image reconstruction loss: 0.5113385915756226 iteration:  155 epoch:  3
# Same Different Classification loss: 0.6320344805717468 iteration:  155 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.1398870944976807 iteration:  160 epoch:  3
# LQ image reconstruction loss: 0.42265933752059937 iteration:  160 epoch:  3
# Same Different Classification loss: 0.59921795129776 iteration:  160 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 1.0232545137405396 iteration:  165 epoch:  3
# LQ image reconstruction loss: 0.42759403586387634 iteration:  165 epoch:  3
# Same Different Classification loss: 0.6309216022491455 iteration:  165 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.995423436164856 iteration:  170 epoch:  3
# LQ image reconstruction loss: 0.5505318641662598 iteration:  170 epoch:  3
# Same Different Classification loss: 0.6366639137268066 iteration:  170 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.937548816204071 iteration:  175 epoch:  3
# LQ image reconstruction loss: 0.4683801829814911 iteration:  175 epoch:  3
# Same Different Classification loss: 0.5926077365875244 iteration:  175 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.9645817875862122 iteration:  180 epoch:  3
# LQ image reconstruction loss: 0.4884645342826843 iteration:  180 epoch:  3
# Same Different Classification loss: 0.593585193157196 iteration:  180 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.9631251096725464 iteration:  185 epoch:  3
# LQ image reconstruction loss: 0.44034919142723083 iteration:  185 epoch:  3
# Same Different Classification loss: 0.6342104077339172 iteration:  185 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.966709315776825 iteration:  190 epoch:  3
# LQ image reconstruction loss: 0.41019824147224426 iteration:  190 epoch:  3
# Same Different Classification loss: 0.6807818412780762 iteration:  190 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.913409411907196 iteration:  195 epoch:  3
# LQ image reconstruction loss: 0.4555610716342926 iteration:  195 epoch:  3
# Same Different Classification loss: 0.648348331451416 iteration:  195 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.8375458121299744 iteration:  200 epoch:  3
# LQ image reconstruction loss: 0.45549583435058594 iteration:  200 epoch:  3
# Same Different Classification loss: 0.6631767153739929 iteration:  200 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 62 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.8988147377967834 iteration:  205 epoch:  3
# LQ image reconstruction loss: 0.4435223639011383 iteration:  205 epoch:  3
# Same Different Classification loss: 0.6138419508934021 iteration:  205 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.835563063621521 iteration:  210 epoch:  3
# LQ image reconstruction loss: 0.4568086862564087 iteration:  210 epoch:  3
# Same Different Classification loss: 0.6290968656539917 iteration:  210 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.7531653046607971 iteration:  215 epoch:  3
# LQ image reconstruction loss: 0.501727283000946 iteration:  215 epoch:  3
# Same Different Classification loss: 0.5900070667266846 iteration:  215 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.7589118480682373 iteration:  220 epoch:  3
# LQ image reconstruction loss: 0.44804441928863525 iteration:  220 epoch:  3
# Same Different Classification loss: 0.6764375567436218 iteration:  220 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.7095250487327576 iteration:  225 epoch:  3
# LQ image reconstruction loss: 0.4040786325931549 iteration:  225 epoch:  3
# Same Different Classification loss: 0.6010596752166748 iteration:  225 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.6563392281532288 iteration:  230 epoch:  3
# LQ image reconstruction loss: 0.4431253671646118 iteration:  230 epoch:  3
# Same Different Classification loss: 0.6311089396476746 iteration:  230 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.7157524228096008 iteration:  235 epoch:  3
# LQ image reconstruction loss: 0.4368133246898651 iteration:  235 epoch:  3
# Same Different Classification loss: 0.6471296548843384 iteration:  235 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.6842539310455322 iteration:  240 epoch:  3
# LQ image reconstruction loss: 0.45779502391815186 iteration:  240 epoch:  3
# Same Different Classification loss: 0.6246846914291382 iteration:  240 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.6900358200073242 iteration:  245 epoch:  3
# LQ image reconstruction loss: 0.4429094195365906 iteration:  245 epoch:  3
# Same Different Classification loss: 0.586185872554779 iteration:  245 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.6712365746498108 iteration:  250 epoch:  3
# LQ image reconstruction loss: 0.39023852348327637 iteration:  250 epoch:  3
# Same Different Classification loss: 0.5423374772071838 iteration:  250 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 56 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.669494092464447 iteration:  255 epoch:  3
# LQ image reconstruction loss: 0.44608306884765625 iteration:  255 epoch:  3
# Same Different Classification loss: 0.6117427945137024 iteration:  255 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.6675366759300232 iteration:  260 epoch:  3
# LQ image reconstruction loss: 0.4631081223487854 iteration:  260 epoch:  3
# Same Different Classification loss: 0.6605381965637207 iteration:  260 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.633937418460846 iteration:  265 epoch:  3
# LQ image reconstruction loss: 0.4712107181549072 iteration:  265 epoch:  3
# Same Different Classification loss: 0.6065824031829834 iteration:  265 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.5783017873764038 iteration:  270 epoch:  3
# LQ image reconstruction loss: 0.3989325761795044 iteration:  270 epoch:  3
# Same Different Classification loss: 0.6000021696090698 iteration:  270 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.622511625289917 iteration:  275 epoch:  3
# LQ image reconstruction loss: 0.4435766637325287 iteration:  275 epoch:  3
# Same Different Classification loss: 0.6855559349060059 iteration:  275 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.5556179881095886 iteration:  280 epoch:  3
# LQ image reconstruction loss: 0.45249006152153015 iteration:  280 epoch:  3
# Same Different Classification loss: 0.6496615409851074 iteration:  280 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.5686485171318054 iteration:  285 epoch:  3
# LQ image reconstruction loss: 0.44348055124282837 iteration:  285 epoch:  3
# Same Different Classification loss: 0.6467726230621338 iteration:  285 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.474476158618927 iteration:  290 epoch:  3
# LQ image reconstruction loss: 0.43394386768341064 iteration:  290 epoch:  3
# Same Different Classification loss: 0.5798272490501404 iteration:  290 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.45357975363731384 iteration:  295 epoch:  3
# LQ image reconstruction loss: 0.4619450271129608 iteration:  295 epoch:  3
# Same Different Classification loss: 0.6964762806892395 iteration:  295 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.489947110414505 iteration:  300 epoch:  3
# LQ image reconstruction loss: 0.44140031933784485 iteration:  300 epoch:  3
# Same Different Classification loss: 0.604326069355011 iteration:  300 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 59 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.46748462319374084 iteration:  305 epoch:  3
# LQ image reconstruction loss: 0.38904309272766113 iteration:  305 epoch:  3
# Same Different Classification loss: 0.6053639054298401 iteration:  305 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.43393373489379883 iteration:  310 epoch:  3
# LQ image reconstruction loss: 0.4619833528995514 iteration:  310 epoch:  3
# Same Different Classification loss: 0.6238954663276672 iteration:  310 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.4556092917919159 iteration:  315 epoch:  3
# LQ image reconstruction loss: 0.4083627760410309 iteration:  315 epoch:  3
# Same Different Classification loss: 0.6810446381568909 iteration:  315 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.43332991003990173 iteration:  320 epoch:  3
# LQ image reconstruction loss: 0.41396141052246094 iteration:  320 epoch:  3
# Same Different Classification loss: 0.6310809850692749 iteration:  320 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.43185722827911377 iteration:  325 epoch:  3
# LQ image reconstruction loss: 0.4229004979133606 iteration:  325 epoch:  3
# Same Different Classification loss: 0.654995322227478 iteration:  325 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.4248988628387451 iteration:  330 epoch:  3
# LQ image reconstruction loss: 0.4397478699684143 iteration:  330 epoch:  3
# Same Different Classification loss: 0.6595354676246643 iteration:  330 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.4130874276161194 iteration:  335 epoch:  3
# LQ image reconstruction loss: 0.4526926279067993 iteration:  335 epoch:  3
# Same Different Classification loss: 0.63569176197052 iteration:  335 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3886231482028961 iteration:  340 epoch:  3
# LQ image reconstruction loss: 0.4281634986400604 iteration:  340 epoch:  3
# Same Different Classification loss: 0.6069270372390747 iteration:  340 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.37916073203086853 iteration:  345 epoch:  3
# LQ image reconstruction loss: 0.4241337478160858 iteration:  345 epoch:  3
# Same Different Classification loss: 0.6963691115379333 iteration:  345 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.45294976234436035 iteration:  350 epoch:  3
# LQ image reconstruction loss: 0.47895076870918274 iteration:  350 epoch:  3
# Same Different Classification loss: 0.6297763586044312 iteration:  350 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 62 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3878900408744812 iteration:  355 epoch:  3
# LQ image reconstruction loss: 0.3810214400291443 iteration:  355 epoch:  3
# Same Different Classification loss: 0.6058534979820251 iteration:  355 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3470678925514221 iteration:  360 epoch:  3
# LQ image reconstruction loss: 0.4365580379962921 iteration:  360 epoch:  3
# Same Different Classification loss: 0.6410273909568787 iteration:  360 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.37512442469596863 iteration:  365 epoch:  3
# LQ image reconstruction loss: 0.4312891364097595 iteration:  365 epoch:  3
# Same Different Classification loss: 0.5758715271949768 iteration:  365 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.37316614389419556 iteration:  370 epoch:  3
# LQ image reconstruction loss: 0.43473100662231445 iteration:  370 epoch:  3
# Same Different Classification loss: 0.6231660842895508 iteration:  370 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.38221731781959534 iteration:  375 epoch:  3
# LQ image reconstruction loss: 0.47324123978614807 iteration:  375 epoch:  3
# Same Different Classification loss: 0.5826185345649719 iteration:  375 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3675025403499603 iteration:  380 epoch:  3
# LQ image reconstruction loss: 0.48170191049575806 iteration:  380 epoch:  3
# Same Different Classification loss: 0.6242585778236389 iteration:  380 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.33522099256515503 iteration:  385 epoch:  3
# LQ image reconstruction loss: 0.453771710395813 iteration:  385 epoch:  3
# Same Different Classification loss: 0.5646366477012634 iteration:  385 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.343744695186615 iteration:  390 epoch:  3
# LQ image reconstruction loss: 0.4551783800125122 iteration:  390 epoch:  3
# Same Different Classification loss: 0.6063592433929443 iteration:  390 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3366367816925049 iteration:  395 epoch:  3
# LQ image reconstruction loss: 0.4335978925228119 iteration:  395 epoch:  3
# Same Different Classification loss: 0.5714945197105408 iteration:  395 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3332022726535797 iteration:  400 epoch:  3
# LQ image reconstruction loss: 0.4371006190776825 iteration:  400 epoch:  3
# Same Different Classification loss: 0.5760497450828552 iteration:  400 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 58 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.345265656709671 iteration:  405 epoch:  3
# LQ image reconstruction loss: 0.44936469197273254 iteration:  405 epoch:  3
# Same Different Classification loss: 0.5862557291984558 iteration:  405 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3257809579372406 iteration:  410 epoch:  3
# LQ image reconstruction loss: 0.4445275068283081 iteration:  410 epoch:  3
# Same Different Classification loss: 0.5813197493553162 iteration:  410 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2905001640319824 iteration:  415 epoch:  3
# LQ image reconstruction loss: 0.4208398759365082 iteration:  415 epoch:  3
# Same Different Classification loss: 0.6242879629135132 iteration:  415 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3077790439128876 iteration:  420 epoch:  3
# LQ image reconstruction loss: 0.43121305108070374 iteration:  420 epoch:  3
# Same Different Classification loss: 0.6138746738433838 iteration:  420 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.27790722250938416 iteration:  425 epoch:  3
# LQ image reconstruction loss: 0.43661198019981384 iteration:  425 epoch:  3
# Same Different Classification loss: 0.6345400810241699 iteration:  425 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3082158863544464 iteration:  430 epoch:  3
# LQ image reconstruction loss: 0.45066630840301514 iteration:  430 epoch:  3
# Same Different Classification loss: 0.5790510177612305 iteration:  430 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.3091200888156891 iteration:  435 epoch:  3
# LQ image reconstruction loss: 0.4440344274044037 iteration:  435 epoch:  3
# Same Different Classification loss: 0.5926387310028076 iteration:  435 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.29201143980026245 iteration:  440 epoch:  3
# LQ image reconstruction loss: 0.446729838848114 iteration:  440 epoch:  3
# Same Different Classification loss: 0.5669680237770081 iteration:  440 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.28491178154945374 iteration:  445 epoch:  3
# LQ image reconstruction loss: 0.43694373965263367 iteration:  445 epoch:  3
# Same Different Classification loss: 0.588564932346344 iteration:  445 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2700888514518738 iteration:  450 epoch:  3
# LQ image reconstruction loss: 0.43486976623535156 iteration:  450 epoch:  3
# Same Different Classification loss: 0.6467837691307068 iteration:  450 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 70 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.26444926857948303 iteration:  455 epoch:  3
# LQ image reconstruction loss: 0.4110313653945923 iteration:  455 epoch:  3
# Same Different Classification loss: 0.5762843489646912 iteration:  455 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.27688369154930115 iteration:  460 epoch:  3
# LQ image reconstruction loss: 0.4165847599506378 iteration:  460 epoch:  3
# Same Different Classification loss: 0.6034039855003357 iteration:  460 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2533029019832611 iteration:  465 epoch:  3
# LQ image reconstruction loss: 0.41783156991004944 iteration:  465 epoch:  3
# Same Different Classification loss: 0.625425398349762 iteration:  465 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2853230834007263 iteration:  470 epoch:  3
# LQ image reconstruction loss: 0.3965003490447998 iteration:  470 epoch:  3
# Same Different Classification loss: 0.5409016609191895 iteration:  470 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.25835609436035156 iteration:  475 epoch:  3
# LQ image reconstruction loss: 0.4389655590057373 iteration:  475 epoch:  3
# Same Different Classification loss: 0.6346794366836548 iteration:  475 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2898101508617401 iteration:  480 epoch:  3
# LQ image reconstruction loss: 0.44969725608825684 iteration:  480 epoch:  3
# Same Different Classification loss: 0.580520749092102 iteration:  480 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2636694610118866 iteration:  485 epoch:  3
# LQ image reconstruction loss: 0.4689064919948578 iteration:  485 epoch:  3
# Same Different Classification loss: 0.6310480833053589 iteration:  485 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.25576162338256836 iteration:  490 epoch:  3
# LQ image reconstruction loss: 0.41229450702667236 iteration:  490 epoch:  3
# Same Different Classification loss: 0.5737664699554443 iteration:  490 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2635137736797333 iteration:  495 epoch:  3
# LQ image reconstruction loss: 0.5145344138145447 iteration:  495 epoch:  3
# Same Different Classification loss: 0.6252840757369995 iteration:  495 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2905144691467285 iteration:  500 epoch:  3
# LQ image reconstruction loss: 0.40432775020599365 iteration:  500 epoch:  3
# Same Different Classification loss: 0.5474717617034912 iteration:  500 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 67 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.267071396112442 iteration:  505 epoch:  3
# LQ image reconstruction loss: 0.3809824585914612 iteration:  505 epoch:  3
# Same Different Classification loss: 0.5803290605545044 iteration:  505 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.28019288182258606 iteration:  510 epoch:  3
# LQ image reconstruction loss: 0.39868950843811035 iteration:  510 epoch:  3
# Same Different Classification loss: 0.5848426222801208 iteration:  510 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.27078351378440857 iteration:  515 epoch:  3
# LQ image reconstruction loss: 0.4228273034095764 iteration:  515 epoch:  3
# Same Different Classification loss: 0.6215296387672424 iteration:  515 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2792312800884247 iteration:  520 epoch:  3
# LQ image reconstruction loss: 0.4330912232398987 iteration:  520 epoch:  3
# Same Different Classification loss: 0.6102855205535889 iteration:  520 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.26877346634864807 iteration:  525 epoch:  3
# LQ image reconstruction loss: 0.4218097925186157 iteration:  525 epoch:  3
# Same Different Classification loss: 0.6345345973968506 iteration:  525 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2644110918045044 iteration:  530 epoch:  3
# LQ image reconstruction loss: 0.4642924666404724 iteration:  530 epoch:  3
# Same Different Classification loss: 0.5404264330863953 iteration:  530 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.26960521936416626 iteration:  535 epoch:  3
# LQ image reconstruction loss: 0.4100465178489685 iteration:  535 epoch:  3
# Same Different Classification loss: 0.5728323459625244 iteration:  535 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.25457316637039185 iteration:  540 epoch:  3
# LQ image reconstruction loss: 0.4513779282569885 iteration:  540 epoch:  3
# Same Different Classification loss: 0.6098335385322571 iteration:  540 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2544746398925781 iteration:  545 epoch:  3
# LQ image reconstruction loss: 0.4551815390586853 iteration:  545 epoch:  3
# Same Different Classification loss: 0.615017294883728 iteration:  545 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.271025687456131 iteration:  550 epoch:  3
# LQ image reconstruction loss: 0.4416438639163971 iteration:  550 epoch:  3
# Same Different Classification loss: 0.6147630214691162 iteration:  550 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 65 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2522043287754059 iteration:  555 epoch:  3
# LQ image reconstruction loss: 0.44292694330215454 iteration:  555 epoch:  3
# Same Different Classification loss: 0.5592442750930786 iteration:  555 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.24654924869537354 iteration:  560 epoch:  3
# LQ image reconstruction loss: 0.42046117782592773 iteration:  560 epoch:  3
# Same Different Classification loss: 0.5576125979423523 iteration:  560 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.22649875283241272 iteration:  565 epoch:  3
# LQ image reconstruction loss: 0.39833706617355347 iteration:  565 epoch:  3
# Same Different Classification loss: 0.5619381666183472 iteration:  565 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.23348228633403778 iteration:  570 epoch:  3
# LQ image reconstruction loss: 0.42595240473747253 iteration:  570 epoch:  3
# Same Different Classification loss: 0.6088166236877441 iteration:  570 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.22087053954601288 iteration:  575 epoch:  3
# LQ image reconstruction loss: 0.38774555921554565 iteration:  575 epoch:  3
# Same Different Classification loss: 0.6059501767158508 iteration:  575 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.23887310922145844 iteration:  580 epoch:  3
# LQ image reconstruction loss: 0.3936438262462616 iteration:  580 epoch:  3
# Same Different Classification loss: 0.5460017919540405 iteration:  580 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.23087985813617706 iteration:  585 epoch:  3
# LQ image reconstruction loss: 0.422889769077301 iteration:  585 epoch:  3
# Same Different Classification loss: 0.5991042852401733 iteration:  585 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.22991400957107544 iteration:  590 epoch:  3
# LQ image reconstruction loss: 0.4319398105144501 iteration:  590 epoch:  3
# Same Different Classification loss: 0.585056483745575 iteration:  590 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.22919757664203644 iteration:  595 epoch:  3
# LQ image reconstruction loss: 0.4258522689342499 iteration:  595 epoch:  3
# Same Different Classification loss: 0.5367904901504517 iteration:  595 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.230921670794487 iteration:  600 epoch:  3
# LQ image reconstruction loss: 0.40771543979644775 iteration:  600 epoch:  3
# Same Different Classification loss: 0.5457105040550232 iteration:  600 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 65 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.25018373131752014 iteration:  605 epoch:  3
# LQ image reconstruction loss: 0.37563496828079224 iteration:  605 epoch:  3
# Same Different Classification loss: 0.5180788636207581 iteration:  605 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2152286320924759 iteration:  610 epoch:  3
# LQ image reconstruction loss: 0.3913773000240326 iteration:  610 epoch:  3
# Same Different Classification loss: 0.6081279516220093 iteration:  610 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.21087901294231415 iteration:  615 epoch:  3
# LQ image reconstruction loss: 0.39339688420295715 iteration:  615 epoch:  3
# Same Different Classification loss: 0.5550763607025146 iteration:  615 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.20202606916427612 iteration:  620 epoch:  3
# LQ image reconstruction loss: 0.3642100691795349 iteration:  620 epoch:  3
# Same Different Classification loss: 0.5673062205314636 iteration:  620 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.23041680455207825 iteration:  625 epoch:  3
# LQ image reconstruction loss: 0.402225136756897 iteration:  625 epoch:  3
# Same Different Classification loss: 0.5417090058326721 iteration:  625 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2394963502883911 iteration:  630 epoch:  3
# LQ image reconstruction loss: 0.4310486912727356 iteration:  630 epoch:  3
# Same Different Classification loss: 0.5947964787483215 iteration:  630 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.20402687788009644 iteration:  635 epoch:  3
# LQ image reconstruction loss: 0.348225861787796 iteration:  635 epoch:  3
# Same Different Classification loss: 0.6595297455787659 iteration:  635 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2009352147579193 iteration:  640 epoch:  3
# LQ image reconstruction loss: 0.40536874532699585 iteration:  640 epoch:  3
# Same Different Classification loss: 0.5652151703834534 iteration:  640 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.2165195643901825 iteration:  645 epoch:  3
# LQ image reconstruction loss: 0.37506186962127686 iteration:  645 epoch:  3
# Same Different Classification loss: 0.6015071868896484 iteration:  645 epoch:  3
# ----------------------------------------------------
# HQ image reconstruction loss: 0.21535232663154602 iteration:  650 epoch:  3
# LQ image reconstruction loss: 0.3519218862056732 iteration:  650 epoch:  3
# Same Different Classification loss: 0.5426543951034546 iteration:  650 epoch:  3
# ----------------------------------------------------
# Accuracy of SD: 67 %
# Mean Accuracy of SD: 55 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.21205173432826996 iteration:  655 epoch:  3
# LQ image reconstruction loss: 0.4130263328552246 iteration:  655 epoch:  3
# Same Different Classification loss: 0.5612584948539734 iteration:  655 epoch:  3
# ...
# HQ image reconstruction loss: 0.14825749397277832 iteration:  2715 epoch:  4
# LQ image reconstruction loss: 0.12970203161239624 iteration:  2715 epoch:  4
# Same Different Classification loss: 0.19125749170780182 iteration:  2715 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.14716976881027222 iteration:  2720 epoch:  4
# LQ image reconstruction loss: 0.13623082637786865 iteration:  2720 epoch:  4
# Same Different Classification loss: 0.2410912662744522 iteration:  2720 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.16231396794319153 iteration:  2725 epoch:  4
# LQ image reconstruction loss: 0.13977764546871185 iteration:  2725 epoch:  4
# Same Different Classification loss: 0.20070205628871918 iteration:  2725 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.16151851415634155 iteration:  2730 epoch:  4
# LQ image reconstruction loss: 0.12112206965684891 iteration:  2730 epoch:  4
# Same Different Classification loss: 0.18668140470981598 iteration:  2730 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.1325858235359192 iteration:  2735 epoch:  4
# LQ image reconstruction loss: 0.13811826705932617 iteration:  2735 epoch:  4
# Same Different Classification loss: 0.21020324528217316 iteration:  2735 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.16322274506092072 iteration:  2740 epoch:  4
# LQ image reconstruction loss: 0.13917769491672516 iteration:  2740 epoch:  4
# Same Different Classification loss: 0.21108995378017426 iteration:  2740 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.1692384034395218 iteration:  2745 epoch:  4
# LQ image reconstruction loss: 0.14217911660671234 iteration:  2745 epoch:  4
# Same Different Classification loss: 0.22778093814849854 iteration:  2745 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.14017194509506226 iteration:  2750 epoch:  4
# LQ image reconstruction loss: 0.14894770085811615 iteration:  2750 epoch:  4
# Same Different Classification loss: 0.2102852761745453 iteration:  2750 epoch:  4
# ----------------------------------------------------
# Accuracy of SD: 94 %
# Mean Accuracy of SD: 66 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.19494222104549408 iteration:  2755 epoch:  4
# LQ image reconstruction loss: 0.15430045127868652 iteration:  2755 epoch:  4
# Same Different Classification loss: 0.22742551565170288 iteration:  2755 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.15009988844394684 iteration:  2760 epoch:  4
# LQ image reconstruction loss: 0.12705324590206146 iteration:  2760 epoch:  4
# Same Different Classification loss: 0.2858663499355316 iteration:  2760 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.151177778840065 iteration:  2765 epoch:  4
# LQ image reconstruction loss: 0.1317310631275177 iteration:  2765 epoch:  4
# Same Different Classification loss: 0.214809849858284 iteration:  2765 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.11673909425735474 iteration:  2770 epoch:  4
# LQ image reconstruction loss: 0.12746897339820862 iteration:  2770 epoch:  4
# Same Different Classification loss: 0.17490160465240479 iteration:  2770 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.11975192278623581 iteration:  2775 epoch:  4
# LQ image reconstruction loss: 0.11805688589811325 iteration:  2775 epoch:  4
# Same Different Classification loss: 0.22162576019763947 iteration:  2775 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.13242663443088531 iteration:  2780 epoch:  4
# LQ image reconstruction loss: 0.14630647003650665 iteration:  2780 epoch:  4
# Same Different Classification loss: 0.2172737866640091 iteration:  2780 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.15297691524028778 iteration:  2785 epoch:  4
# LQ image reconstruction loss: 0.1330789029598236 iteration:  2785 epoch:  4
# Same Different Classification loss: 0.21014779806137085 iteration:  2785 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.15976198017597198 iteration:  2790 epoch:  4
# LQ image reconstruction loss: 0.13681398332118988 iteration:  2790 epoch:  4
# Same Different Classification loss: 0.21302250027656555 iteration:  2790 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.1479019820690155 iteration:  2795 epoch:  4
# LQ image reconstruction loss: 0.12131435424089432 iteration:  2795 epoch:  4
# Same Different Classification loss: 0.21665863692760468 iteration:  2795 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.15201112627983093 iteration:  2800 epoch:  4
# LQ image reconstruction loss: 0.12194879353046417 iteration:  2800 epoch:  4
# Same Different Classification loss: 0.23907382786273956 iteration:  2800 epoch:  4
# ----------------------------------------------------
# Accuracy of SD: 92 %
# Mean Accuracy of SD: 66 %
# ----------------------------------------------------
# HQ image reconstruction loss: 0.1425551325082779 iteration:  2805 epoch:  4
# LQ image reconstruction loss: 0.14707162976264954 iteration:  2805 epoch:  4
# Same Different Classification loss: 0.2072620391845703 iteration:  2805 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.11381389200687408 iteration:  2810 epoch:  4
# LQ image reconstruction loss: 0.14974606037139893 iteration:  2810 epoch:  4
# Same Different Classification loss: 0.19032172858715057 iteration:  2810 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.10662654042243958 iteration:  2815 epoch:  4
# LQ image reconstruction loss: 0.134341761469841 iteration:  2815 epoch:  4
# Same Different Classification loss: 0.1930943876504898 iteration:  2815 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.13676591217517853 iteration:  2820 epoch:  4
# LQ image reconstruction loss: 0.12931185960769653 iteration:  2820 epoch:  4
# Same Different Classification loss: 0.2222348004579544 iteration:  2820 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.1065838634967804 iteration:  2825 epoch:  4
# LQ image reconstruction loss: 0.14167267084121704 iteration:  2825 epoch:  4
# Same Different Classification loss: 0.2259932905435562 iteration:  2825 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.13497576117515564 iteration:  2830 epoch:  4
# LQ image reconstruction loss: 0.1358065903186798 iteration:  2830 epoch:  4
# Same Different Classification loss: 0.24090775847434998 iteration:  2830 epoch:  4
# ----------------------------------------------------
# HQ image reconstruction loss: 0.13901682198047638 iteration:  2835 epoch:  4
# LQ image reconstruction loss: 0.1342126727104187 iteration:  2835 epoch:  4
# Same Different Classification loss: 0.23112891614437103 iteration:  2835 epoch:  4
# ----------------------------------------------------
# {'gender': -1,
#  'image1': tensor([[[0.0010, 0.0010, 0.0010,  ..., 0.0011, 0.0012, 0.0013],
#           [0.0010, 0.0010, 0.0010,  ..., 0.0011, 0.0012, 0.0014],
#           [0.0010, 0.0010, 0.0010,  ..., 0.0011, 0.0012, 0.0014],
#           ...,
#           [0.0032, 0.0034, 0.0033,  ..., 0.0020, 0.0022, 0.0022],
#           [0.0033, 0.0034, 0.0033,  ..., 0.0020, 0.0021, 0.0022],
#           [0.0035, 0.0034, 0.0033,  ..., 0.0021, 0.0022, 0.0021]],
#
#          [[0.0008, 0.0008, 0.0008,  ..., 0.0010, 0.0012, 0.0013],
#           [0.0008, 0.0008, 0.0008,  ..., 0.0011, 0.0012, 0.0013],
#           [0.0008, 0.0008, 0.0008,  ..., 0.0011, 0.0012, 0.0013],
#           ...,
#           [0.0032, 0.0035, 0.0033,  ..., 0.0015, 0.0018, 0.0019],
#           [0.0033, 0.0034, 0.0033,  ..., 0.0015, 0.0016, 0.0018],
#           [0.0034, 0.0033, 0.0032,  ..., 0.0017, 0.0019, 0.0018]],
#
#          [[0.0007, 0.0007, 0.0007,  ..., 0.0010, 0.0011, 0.0012],
#           [0.0007, 0.0007, 0.0007,  ..., 0.0010, 0.0011, 0.0012],
#           [0.0007, 0.0007, 0.0007,  ..., 0.0010, 0.0011, 0.0012],
#           ...,
#           [0.0033, 0.0035, 0.0034,  ..., 0.0015, 0.0018, 0.0019],
#           [0.0034, 0.0034, 0.0033,  ..., 0.0014, 0.0016, 0.0018],
#           [0.0035, 0.0034, 0.0033,  ..., 0.0016, 0.0018, 0.0017]]]),
#  'image2': tensor([[[0.0011, 0.0018, 0.0020, 0.0014, 0.0012, 0.0013, 0.0011, 0.0012,
#            0.0015, 0.0019, 0.0022, 0.0024, 0.0023, 0.0019, 0.0016, 0.0013],
#           [0.0010, 0.0016, 0.0014, 0.0008, 0.0011, 0.0013, 0.0013, 0.0014,
#            0.0017, 0.0020, 0.0023, 0.0023, 0.0021, 0.0016, 0.0013, 0.0010],
#           [0.0012, 0.0017, 0.0012, 0.0006, 0.0011, 0.0018, 0.0023, 0.0023,
#            0.0024, 0.0024, 0.0026, 0.0026, 0.0022, 0.0018, 0.0010, 0.0007],
#           [0.0010, 0.0016, 0.0012, 0.0007, 0.0011, 0.0022, 0.0019, 0.0017,
#            0.0016, 0.0017, 0.0019, 0.0020, 0.0020, 0.0021, 0.0018, 0.0016],
#           [0.0007, 0.0009, 0.0009, 0.0007, 0.0010, 0.0022, 0.0021, 0.0022,
#            0.0022, 0.0023, 0.0019, 0.0018, 0.0018, 0.0017, 0.0022, 0.0027],
#           [0.0007, 0.0006, 0.0007, 0.0007, 0.0012, 0.0028, 0.0031, 0.0032,
#            0.0033, 0.0034, 0.0031, 0.0026, 0.0022, 0.0018, 0.0018, 0.0021],
#           [0.0009, 0.0008, 0.0007, 0.0008, 0.0012, 0.0028, 0.0032, 0.0033,
#            0.0033, 0.0034, 0.0033, 0.0029, 0.0023, 0.0018, 0.0017, 0.0020],
#           [0.0008, 0.0010, 0.0011, 0.0010, 0.0015, 0.0025, 0.0023, 0.0029,
#            0.0028, 0.0027, 0.0030, 0.0032, 0.0028, 0.0019, 0.0015, 0.0019],
#           [0.0006, 0.0011, 0.0016, 0.0013, 0.0016, 0.0024, 0.0020, 0.0030,
#            0.0026, 0.0019, 0.0024, 0.0032, 0.0031, 0.0021, 0.0020, 0.0015],
#           [0.0005, 0.0014, 0.0022, 0.0018, 0.0021, 0.0028, 0.0027, 0.0033,
#            0.0031, 0.0029, 0.0032, 0.0034, 0.0032, 0.0029, 0.0021, 0.0009],
#           [0.0007, 0.0018, 0.0027, 0.0030, 0.0034, 0.0023, 0.0022, 0.0024,
#            0.0027, 0.0024, 0.0026, 0.0030, 0.0028, 0.0022, 0.0014, 0.0008],
#           [0.0013, 0.0021, 0.0030, 0.0036, 0.0036, 0.0028, 0.0020, 0.0021,
#            0.0023, 0.0023, 0.0025, 0.0027, 0.0018, 0.0006, 0.0008, 0.0010],
#           [0.0012, 0.0021, 0.0029, 0.0032, 0.0035, 0.0031, 0.0025, 0.0025,
#            0.0028, 0.0029, 0.0027, 0.0024, 0.0014, 0.0006, 0.0011, 0.0019],
#           [0.0009, 0.0012, 0.0014, 0.0018, 0.0031, 0.0028, 0.0027, 0.0025,
#            0.0024, 0.0025, 0.0024, 0.0023, 0.0017, 0.0011, 0.0025, 0.0024],
#           [0.0012, 0.0014, 0.0014, 0.0020, 0.0029, 0.0030, 0.0030, 0.0022,
#            0.0016, 0.0020, 0.0024, 0.0022, 0.0015, 0.0010, 0.0021, 0.0027],
#           [0.0023, 0.0026, 0.0027, 0.0025, 0.0024, 0.0025, 0.0026, 0.0019,
#            0.0017, 0.0018, 0.0022, 0.0019, 0.0015, 0.0013, 0.0017, 0.0021]],
#
#          [[0.0009, 0.0014, 0.0017, 0.0012, 0.0012, 0.0014, 0.0012, 0.0013,
#            0.0016, 0.0020, 0.0023, 0.0024, 0.0022, 0.0018, 0.0015, 0.0012],
#           [0.0009, 0.0013, 0.0012, 0.0007, 0.0011, 0.0014, 0.0013, 0.0015,
#            0.0017, 0.0020, 0.0023, 0.0022, 0.0019, 0.0015, 0.0012, 0.0010],
#           [0.0010, 0.0014, 0.0010, 0.0005, 0.0010, 0.0016, 0.0018, 0.0017,
#            0.0019, 0.0020, 0.0019, 0.0018, 0.0016, 0.0014, 0.0008, 0.0005],
#           [0.0008, 0.0013, 0.0010, 0.0005, 0.0008, 0.0015, 0.0012, 0.0010,
#            0.0010, 0.0010, 0.0011, 0.0011, 0.0011, 0.0013, 0.0013, 0.0013],
#           [0.0006, 0.0007, 0.0008, 0.0006, 0.0008, 0.0015, 0.0015, 0.0017,
#            0.0018, 0.0020, 0.0013, 0.0010, 0.0009, 0.0009, 0.0013, 0.0022],
#           [0.0008, 0.0007, 0.0007, 0.0008, 0.0010, 0.0022, 0.0026, 0.0029,
#            0.0030, 0.0031, 0.0026, 0.0017, 0.0012, 0.0009, 0.0010, 0.0013],
#           [0.0012, 0.0011, 0.0009, 0.0010, 0.0011, 0.0024, 0.0029, 0.0030,
#            0.0030, 0.0031, 0.0031, 0.0023, 0.0014, 0.0009, 0.0009, 0.0010],
#           [0.0011, 0.0013, 0.0013, 0.0011, 0.0012, 0.0021, 0.0020, 0.0025,
#            0.0024, 0.0023, 0.0027, 0.0028, 0.0023, 0.0012, 0.0008, 0.0010],
#           [0.0009, 0.0014, 0.0019, 0.0014, 0.0013, 0.0021, 0.0016, 0.0026,
#            0.0022, 0.0016, 0.0020, 0.0028, 0.0026, 0.0016, 0.0014, 0.0008],
#           [0.0008, 0.0017, 0.0025, 0.0021, 0.0021, 0.0024, 0.0023, 0.0029,
#            0.0027, 0.0025, 0.0027, 0.0028, 0.0027, 0.0024, 0.0016, 0.0004],
#           [0.0010, 0.0021, 0.0029, 0.0032, 0.0034, 0.0019, 0.0017, 0.0019,
#            0.0022, 0.0019, 0.0020, 0.0024, 0.0023, 0.0017, 0.0009, 0.0003],
#           [0.0013, 0.0023, 0.0032, 0.0036, 0.0037, 0.0026, 0.0015, 0.0016,
#            0.0018, 0.0018, 0.0020, 0.0022, 0.0014, 0.0003, 0.0003, 0.0005],
#           [0.0012, 0.0021, 0.0030, 0.0033, 0.0036, 0.0031, 0.0021, 0.0019,
#            0.0023, 0.0024, 0.0022, 0.0020, 0.0010, 0.0002, 0.0006, 0.0017],
#           [0.0011, 0.0014, 0.0017, 0.0020, 0.0032, 0.0029, 0.0024, 0.0021,
#            0.0020, 0.0020, 0.0019, 0.0018, 0.0013, 0.0007, 0.0021, 0.0024],
#           [0.0015, 0.0017, 0.0017, 0.0022, 0.0030, 0.0030, 0.0028, 0.0018,
#            0.0012, 0.0015, 0.0019, 0.0017, 0.0010, 0.0004, 0.0015, 0.0025],
#           [0.0024, 0.0027, 0.0029, 0.0027, 0.0026, 0.0025, 0.0024, 0.0015,
#            0.0013, 0.0013, 0.0016, 0.0013, 0.0008, 0.0006, 0.0009, 0.0016]],
#
#          [[0.0008, 0.0013, 0.0015, 0.0011, 0.0012, 0.0014, 0.0012, 0.0015,
#            0.0017, 0.0020, 0.0024, 0.0024, 0.0021, 0.0017, 0.0015, 0.0011],
#           [0.0008, 0.0012, 0.0011, 0.0007, 0.0012, 0.0014, 0.0014, 0.0016,
#            0.0019, 0.0021, 0.0023, 0.0021, 0.0019, 0.0014, 0.0011, 0.0009],
#           [0.0009, 0.0013, 0.0009, 0.0005, 0.0010, 0.0016, 0.0019, 0.0017,
#            0.0019, 0.0020, 0.0018, 0.0017, 0.0016, 0.0013, 0.0007, 0.0005],
#           [0.0008, 0.0011, 0.0009, 0.0005, 0.0008, 0.0015, 0.0011, 0.0009,
#            0.0009, 0.0010, 0.0009, 0.0010, 0.0011, 0.0013, 0.0011, 0.0012],
#           [0.0005, 0.0007, 0.0007, 0.0006, 0.0008, 0.0014, 0.0013, 0.0015,
#            0.0016, 0.0018, 0.0011, 0.0008, 0.0008, 0.0008, 0.0012, 0.0020],
#           [0.0008, 0.0008, 0.0008, 0.0008, 0.0011, 0.0021, 0.0024, 0.0027,
#            0.0029, 0.0030, 0.0024, 0.0014, 0.0010, 0.0008, 0.0009, 0.0011],
#           [0.0013, 0.0012, 0.0010, 0.0011, 0.0011, 0.0022, 0.0027, 0.0028,
#            0.0029, 0.0030, 0.0029, 0.0020, 0.0012, 0.0008, 0.0008, 0.0008],
#           [0.0013, 0.0014, 0.0014, 0.0012, 0.0012, 0.0020, 0.0018, 0.0023,
#            0.0022, 0.0021, 0.0025, 0.0026, 0.0021, 0.0010, 0.0007, 0.0007],
#           [0.0011, 0.0015, 0.0020, 0.0015, 0.0013, 0.0020, 0.0015, 0.0024,
#            0.0020, 0.0014, 0.0019, 0.0025, 0.0024, 0.0013, 0.0011, 0.0005],
#           [0.0009, 0.0018, 0.0026, 0.0021, 0.0020, 0.0023, 0.0021, 0.0028,
#            0.0026, 0.0024, 0.0027, 0.0027, 0.0024, 0.0021, 0.0014, 0.0003],
#           [0.0011, 0.0021, 0.0029, 0.0031, 0.0033, 0.0018, 0.0015, 0.0017,
#            0.0021, 0.0018, 0.0018, 0.0022, 0.0021, 0.0015, 0.0008, 0.0001],
#           [0.0013, 0.0023, 0.0032, 0.0036, 0.0035, 0.0024, 0.0014, 0.0015,
#            0.0017, 0.0017, 0.0016, 0.0019, 0.0013, 0.0002, 0.0002, 0.0004],
#           [0.0012, 0.0021, 0.0029, 0.0032, 0.0034, 0.0030, 0.0020, 0.0018,
#            0.0021, 0.0022, 0.0019, 0.0017, 0.0009, 0.0001, 0.0006, 0.0018],
#           [0.0012, 0.0015, 0.0018, 0.0021, 0.0030, 0.0028, 0.0024, 0.0019,
#            0.0018, 0.0017, 0.0017, 0.0015, 0.0010, 0.0006, 0.0021, 0.0026],
#           [0.0016, 0.0018, 0.0018, 0.0023, 0.0030, 0.0030, 0.0026, 0.0017,
#            0.0010, 0.0013, 0.0016, 0.0014, 0.0008, 0.0003, 0.0013, 0.0025],
#           [0.0025, 0.0029, 0.0030, 0.0028, 0.0027, 0.0026, 0.0022, 0.0013,
#            0.0011, 0.0011, 0.0014, 0.0011, 0.0006, 0.0004, 0.0007, 0.0015]]]),
#  'same': 1}

# %%
# import numpy as np

# val_index1 = np.random.permutation(val_index)[:100]
# val_dataloader = DataLoader(dataset,batch_size=50,sampler = SubsetRandomSampler(test_index))
# val_iter = iter(val_dataloader)
# predicted_lables = []
# real_labels_g = []
# predicted_lables_g = []
# real_labels = []
# real_labels_y = []
# predicted_lables_y = []
# predicted_lables_F=[]
# predicted_lables_M=[]
# real_labels_F = []
# real_labels_M = []

# total = 0
# total_F = 0
# total_M = 0
# correct1_SD = 0
# correct1_MF = 0
# correct_M = 0
# correct_F = 0
# correct1_YO = 0
# acc1=[]
# acc2=[]
# acc_M = []
# acc_F = []
# acc1_YO = []
# for j,dataj in enumerate(val_dataloader):
#             input1, input2 , label, gender ,young= data.items()
#             input1, input2 = input1[1].to(device), input2[1].to(device)
#             labelj = label[1].to(device)
#             gender = gender[1].to(device)
#             young = young[1].to(device)
#             gender = (gender+torch.ones_like(gender).to(device))//2
#             young = (young+torch.ones_like(young).to(device))//2

#             mu_all = torch.cat((mu_high,mu_low.data),1)
#             logvar_all = torch.cat((logvar_high,logvar_low),1)
#             class_input = torch.cat((mu_all,logvar_all),1)
#             #class_input = mu_all
#             class_out_SD = class_net_SD(class_input)
#             class_out_MF = class_net_MF(class_input)
#             class_out_YO = class_net_YO(class_input)
#             _,predicted1_SD = torch.max(class_out_SD.data,1)
#             _,predicted1_MF = torch.max(class_out_MF.data,1)
#             _,predicted1_YO = torch.max(class_out_YO.data,1)
#             # _,predicted2 = torch.max(output_A.data,1)
#             total +=labelj.size(0)
#             correct1_SD += (predicted1_SD == labelj).sum().item()
#             correct1_MF += (predicted1_MF == gender).sum().item()
#             # for gender == 0
#             correct_F += (predicted1_MF[gender==0] == gender[gender==0]).sum().item()
#             total_F += len(gender[gender==0])
#             predicted_lables_F.append(torch.Tensor.numpy(predicted1_MF[gender==0].cpu()))
#             real_labels_F.append(torch.Tensor.numpy(gender[gender==0].cpu()))

#              # for gender == 1
#             correct_M += (predicted1_MF[gender==1] == gender[gender==1]).sum().item()
#             total_M += gender[gender==1].sum().item()

#             predicted_lables_M.append(torch.Tensor.numpy(predicted1_MF[gender==1].cpu()))
#             real_labels_M.append(torch.Tensor.numpy(gender[gender==1].cpu()))



#             correct1_YO += (predicted1_YO == young).sum().item()
#             predicted_lables.append(torch.Tensor.numpy(predicted1_SD.cpu()))
#             real_labels.append(torch.Tensor.numpy(labelj.cpu()))

#             predicted_lables_g.append(torch.Tensor.numpy(predicted1_MF.cpu()))
#             real_labels_g.append(torch.Tensor.numpy(gender.cpu()))
#             predicted_lables_y.append(torch.Tensor.numpy(predicted1_YO.cpu()))
#             real_labels_y.append(torch.Tensor.numpy(young.cpu()))

#             # correct2 += (predicted2 == gender).sum().item()
#             print('Accuracy of SD: %d %%'%(100*correct1_SD/total))
#             print('Accuracy of MF: %d %%'%(100*correct1_MF/total))
#             print('Accuracy of F: %d %%'%(100*correct_F/total_F))
#             print('Accuracy of M: %d %%'%(100*correct_M/total_M))

#             print('Accuracy of YO: %d %%'%(100*correct1_YO/total))

           
#             acc1.append(100*correct1_SD/total)
#             acc2.append(100*correct1_MF/total)
#             acc1_YO.append(100*correct1_YO/total)
#             print('confusion matrix for same differen')
#             print(mt.confusion_matrix(np.array(real_labels).flatten(),np.array(predicted_lables).flatten()))
#             print('confusion matrix for female')
#             print(mt.confusion_matrix(np.array(real_labels_F).flatten(),np.array(predicted_lables_F).flatten()))
#             print('confusion matrix for male')
#             print(mt.confusion_matrix(np.array(real_labels_M).flatten(),np.array(predicted_lables_M).flatten()))
#             print('confusion matrix for male female')
#             print(mt.confusion_matrix(np.array(real_labels_g).flatten(),np.array(predicted_lables_g).flatten()))
#             print('confusion matrix for young old')
#             print(mt.confusion_matrix(np.array(real_labels_y).flatten(),np.array(predicted_lables_y).flatten()))

# %%
val_index1 = np.random.permutation(val_index)[:100]
val_dataloader = DataLoader(dataset,batch_size=50,sampler = SubsetRandomSampler(test_index))
val_iter = iter(val_dataloader)
predicted_lables = []
real_labels_g = []
predicted_lables_g = []
real_labels = []
total = 0
correct1_SD = 0
correct1_MF = 0
acc1=[]
acc2=[]
for j,dataj in enumerate(val_dataloader):
            input1j, input2j, labelj, gender = dataj.items()
            input1j, input2j = input1j[1].to(device), input2j[1].to(device)

            labelj = labelj[1].to(device)
            gender = gender[1].to(device)
            gender = (gender+torch.ones_like(gender).to(device))//2
            recon_batch_high, mu_high, logvar_high, h2_h = model_high(input1j)
            recon_batch_low, mu_low, logvar_low, h2_l = model_low(input2j)

            mu_all = torch.cat((mu_high,mu_low.data),1)
            logvar_all = torch.cat((logvar_high,logvar_low),1)
            class_input = torch.cat((mu_all,logvar_all),1)
            #class_input = mu_all
            class_out_SD = class_net_SD(class_input)
            # class_out_MF = class_net_MF(class_input)
            _,predicted1_SD = torch.max(class_out_SD.data,1)
            # _,predicted1_MF = torch.max(class_out_MF.data,1)
            # _,predicted2 = torch.max(output_A.data,1)
            total +=labelj.size(0)
            correct1_SD += (predicted1_SD == labelj).sum().item()
            # correct1_MF += (predicted1_MF == gender).sum().item()
            predicted_lables.append(torch.Tensor.numpy(predicted1_SD.cpu()))
            real_labels.append(torch.Tensor.numpy(labelj.cpu()))

            # predicted_lables_g.append(torch.Tensor.numpy(predicted1_MF.cpu()))
            # real_labels_g.append(torch.Tensor.numpy(gender.cpu()))
            # correct2 += (predicted2 == gender).sum().item()
            print('Accuracy of SD: %d %%'%(100*correct1_SD/total))
            # print('Accuracy of MF: %d %%'%(100*correct1_MF/total))

           
            acc1.append(100*correct1_SD/total)
            # acc2.append(100*correct1_MF/total)
            print(mt.confusion_matrix(np.array(real_labels).flatten(),np.array(predicted_lables).flatten()))
            
            # print(mt.confusion_matrix(np.array(real_labels_g).flatten(),np.array(predicted_lables_g).flatten()))
